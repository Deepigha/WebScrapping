# %%
import requests
from bs4 import BeautifulSoup as BS
URL = "https://www.zomato.com/chennai/great-food-no-bull"
headers = {
    'authority': 'www.zomato.com',
'method': 'GET',
'path': '/chennai/dine-out',
'scheme': 'https',
'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"macOS"',
'sec-fetch-dest': 'document',
'sec-fetch-mode': 'navigate',
'sec-fetch-site': 'same-origin',
'sec-fetch-user': '?1',
'upgrade-insecure-requests': '1',
'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.134 Safari/537.36'
}

page = requests.get(URL, headers=headers)

soup = BS(page.content, "html.parser")

# print(page.content)

# %%
top_rest = soup.find_all("div",attrs={"class": "sc-laTMn gITREa"})

# print(top_rest)

list_tr = top_rest[0].find_all("div",attrs={"class": "sc-gykZtl cNbqkQ"})
list_rest =[]
for tr in list_tr:
    dataframe ={}
    dataframe["RestaurantName"] = (tr.find("a",attrs={"class": "sc-lljKfs sc-ffCbqV dKlSrU"})).text.replace('\n', ' ')
    attr = tr.find("a",attrs={"class": "sc-lljKfs sc-ffCbqV dKlSrU"})
    dataframe["RestaurantURL"] = attr["href"]
    dataframe["CuisineType"] = (tr.find("div",attrs={"class":"sc-ldQhTJ hlojsD"})).text.replace('\n', ' ')
    list_rest.append(dataframe)
# print(list_rest)

# %%
print(dataframe)
# Out:
# {'RestaurantName': 'Royal Indianaa - The Accord Metropolitan', 'RestaurantURL': 'https://www.zomato.com/chennai/royal-indianaa-the-accord-metropolitan-1-t-nagar?zrp_bid=0&zrp_pid=14', 'CuisineType': 'South Indian,\xa0North Indian'}

# %%
import pandas
df = pandas.DataFrame(list_rest)
df.to_csv("zomato_res.csv",index=False)

# %%
df
# Out:
#                               RestaurantName  \
# 0                                Haagen Dazs
# 1               MKC - Madras Kitchen Company
# 2            Southern Spice - Taj Coromandel
# 3                                  SpiceKlub
# 4                          The Sandwich Shop
# ..                                       ...
# 70                      Gossip Fusion Bistro
# 71                         Murugan Idli Shop
# 72                                 BurgerMan
# 73                             The Brew Room
# 74  Royal Indianaa - The Accord Metropolitan
#
#                                         RestaurantURL  \
# 0   https://www.zomato.com/chennai/haagen-dazs-nun...
# 1   https://www.zomato.com/chennai/mkc-madras-kitc...
# 2   https://www.zomato.com/chennai/southern-spice-...
# 3   https://www.zomato.com/chennai/spiceklub-nunga...
# 4   https://www.zomato.com/chennai/the-sandwich-sh...
# ..                                                ...
# 70  https://www.zomato.com/chennai/gossip-fusion-b...
# 71  https://www.zomato.com/chennai/murugan-idli-sh...
# 72  https://www.zomato.com/chennai/burgerman-besan...
# 73  https://www.zomato.com/chennai/the-brew-room-a...
# 74  https://www.zomato.com/chennai/royal-indianaa-...
#
#                                           CuisineType
# 0                      Ice Cream, Desserts, Beverages
# 1      Cafe, Asian, North Indian, Desserts, Beverages
# 2                                        South Indian
# 3                   North Indian, Desserts, Beverages
# 4      Sandwich, Fast Food, Beverages, Shake, Sichuan
# ..                                                ...
# 70  Italian, Salad, Seafood, Kerala, North Indian,...
# 71                  South Indian, Desserts, Beverages
# 72      Burger, Fast Food, Salad, Desserts, Beverages
# 73               Cafe, Continental, Italian, Desserts
# 74                         South Indian, North Indian
#
# [75 rows x 3 columns]
