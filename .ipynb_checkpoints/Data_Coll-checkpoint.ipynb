# %%
import requests
from bs4 import BeautifulSoup as BS
URL = "https://www.zomato.com/chennai/great-food-no-bull"
headers = {
    'authority': 'www.zomato.com',
'method': 'GET',
'path': '/chennai/dine-out',
'scheme': 'https',
'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"macOS"',
'sec-fetch-dest': 'document',
'sec-fetch-mode': 'navigate',
'sec-fetch-site': 'same-origin',
'sec-fetch-user': '?1',
'upgrade-insecure-requests': '1',
'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.134 Safari/537.36'
}

page = requests.get(URL, headers=headers)

soup = BS(page.content, "html.parser")

# print(page.content)

# %%
top_rest = soup.find_all("div",attrs={"class": "sc-laTMn gITREa"})

# print(top_rest)

list_tr = top_rest[0].find_all("div",attrs={"class": "sc-bke1zw-1"})
# print("list_lr")
# print(list_tr)
list_rest =[]
for tr in list_tr:
    dataframe ={}
    dataframe["RestaurantName"] = (tr.find("a",attrs={"class": "sc-kKsMzK sc-bwNswr cqWHvO"})).text.replace('\n', ' ')
    attr = tr.find("a",attrs={"class": "sc-kKsMzK sc-bwNswr cqWHvO"})
    dataframe["RestaurantURL"] = attr["href"]
    dataframe["CuisineType"] = (tr.find("div",attrs={"class":"sc-jOnmPf FOTlX"})).text.replace('\n', ' ')
    list_rest.append(dataframe)
#     print(list_rest)
# Out:
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# {'RestaurantName': 'Barbeque Nation', 'RestaurantURL': 'https://www.zomato.com/chennai/barbeque-nation-t-nagar?zrp_bid=1198677&zrp_pid=14&zrp_cid=10089442', 'CuisineType': 'BBQ,\xa0Kebab,\xa0North Indian,\xa0Desserts,\xa0Beverages'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [302], in <cell line: 9>()
#       9 for tr in list_tr:
#      10 #     print(tr.find("a",attrs={"class":"sc-kKsMzK sc-bwNswr cqWHvO"}).text)
#      11 #     print("tr", tr)
#    (...)
#      23 #     print(tr.find("div",attrs={"class": "sc-gsVOdK gUhFHk"}).text.replace('\n', ' '))
#      24 #     break
#      25     dataframe ={}
# ---> 26     dataframe["RestaurantName"] = (tr.find("a",attrs={"class": "sc-kKsMzK sc-bwNswr cqWHvO"})).text.replace('\n', ' ')
#      27     attr = tr.find("a",attrs={"class": "sc-kKsMzK sc-bwNswr cqWHvO"})
#      28 #     print(attr["href"])
#
# AttributeError: 'NoneType' object has no attribute 'text'
